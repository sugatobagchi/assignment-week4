# %%
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import KBinsDiscretizer
from mlxtend.frequent_patterns import apriori, association_rules

df = pd.read_csv('market.csv', sep="\t")

continuous_features = ['Income', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']
imputer = SimpleImputer(strategy='mean')
df[continuous_features] = imputer.fit_transform(df[continuous_features])
df[continuous_features] = df[continuous_features].apply(lambda x: x > 0).astype(int)

categorical_features = ['Education', 'Marital_Status']
df = pd.get_dummies(df, columns=categorical_features)

binary_columns = df.columns[df.isin([0, 1]).all()]

frequent_itemsets = apriori(df[binary_columns], min_support=0.05, use_colnames=True)
rules = association_rules(frequent_itemsets, metric='confidence', min_threshold=0.5)

rules['leverage'] = rules['support'] - (rules['antecedent support'] * rules['consequent support'])
rules['conviction'] = (1 - rules['consequent support']) / (1 - rules['confidence'])

rules_sorted = rules.sort_values(by=['lift', 'confidence', 'support', 'leverage', 'conviction'], ascending=False)
rules_sorted.to_csv('association_rules.csv', index=False)

print(rules_sorted.head(10))
# Out:
# /home/sugato/.local/lib/python3.12/site-packages/mlxtend/frequent_patterns/fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                                              antecedents  \
# 24598  (MntMeatProducts, Education_2n Cycle, MntFishP...
# 30761  (MntMeatProducts, Education_2n Cycle, MntFishP...
# 30779  (MntMeatProducts, Education_2n Cycle, MntFishP...
# 23344    (Education_2n Cycle, MntWines, MntFishProducts)
# 28203  (Education_2n Cycle, MntWines, MntFishProducts...
# 28219    (Education_2n Cycle, MntWines, MntFishProducts)
# 32188  (MntMeatProducts, Education_2n Cycle, MntWines...
# 32213    (Education_2n Cycle, MntWines, MntFishProducts)
# 33909  (MntMeatProducts, MntFishProducts, MntWines, E...
# 33940  (MntMeatProducts, Education_2n Cycle, MntWines...
#
#                                              consequents  antecedent support  \
# 24598        (MntGoldProds, MntSweetProducts, MntFruits)            0.081696
# 30761        (MntGoldProds, MntSweetProducts, MntFruits)            0.081696
# 30779  (MntGoldProds, MntFruits, MntSweetProducts, In...            0.081696
# 23344        (MntGoldProds, MntSweetProducts, MntFruits)            0.080357
# 28203        (MntGoldProds, MntSweetProducts, MntFruits)            0.080357
# 28219  (MntGoldProds, MntFruits, MntSweetProducts, In...            0.080357
# 32188        (MntGoldProds, MntSweetProducts, MntFruits)            0.080357
# 32213  (MntGoldProds, MntMeatProducts, MntSweetProduc...            0.080357
# 33909        (MntGoldProds, MntSweetProducts, MntFruits)            0.080357
# 33940  (MntGoldProds, MntFruits, MntSweetProducts, In...            0.080357
#
#        consequent support   support  confidence      lift  leverage  \
# 24598            0.713393  0.074107    0.907104  1.271535  0.015825
# 30761            0.713393  0.074107    0.907104  1.271535  0.015825
# 30779            0.713393  0.074107    0.907104  1.271535  0.015825
# 23344            0.713393  0.072768    0.905556  1.269364  0.015442
# 28203            0.713393  0.072768    0.905556  1.269364  0.015442
# 28219            0.713393  0.072768    0.905556  1.269364  0.015442
# 32188            0.713393  0.072768    0.905556  1.269364  0.015442
# 32213            0.713393  0.072768    0.905556  1.269364  0.015442
# 33909            0.713393  0.072768    0.905556  1.269364  0.015442
# 33940            0.713393  0.072768    0.905556  1.269364  0.015442
#
#        conviction  zhangs_metric
# 24598    3.085242       0.232547
# 30761    3.085242       0.232547
# 30779    3.085242       0.232547
# 23344    3.034664       0.230746
# 28203    3.034664       0.230746
# 28219    3.034664       0.230746
# 32188    3.034664       0.230746
# 32213    3.034664       0.230746
# 33909    3.034664       0.230746
# 33940    3.034664       0.230746

# %%
rules_sorted = rules.sort_values(by=['lift'], ascending=False)
rules_sorted.to_csv('rules_by_lift.csv', index=False)
rules_sorted.head(10)
# Out:
#                                              antecedents  \
# 30779  (MntMeatProducts, Education_2n Cycle, MntFishP...
# 30761  (MntMeatProducts, Education_2n Cycle, MntFishP...
# 24598  (MntMeatProducts, Education_2n Cycle, MntFishP...
# 32213    (Education_2n Cycle, MntWines, MntFishProducts)
# 32188  (MntMeatProducts, Education_2n Cycle, MntWines...
# 33959  (Education_2n Cycle, MntWines, MntFishProducts...
# 28203  (Education_2n Cycle, MntWines, MntFishProducts...
# 33981    (Education_2n Cycle, MntWines, MntFishProducts)
# 33940  (MntMeatProducts, Education_2n Cycle, MntWines...
# 33909  (MntMeatProducts, MntFishProducts, MntWines, E...
#
#                                              consequents  antecedent support  \
# 30779  (MntGoldProds, MntFruits, MntSweetProducts, In...            0.081696
# 30761        (MntGoldProds, MntSweetProducts, MntFruits)            0.081696
# 24598        (MntGoldProds, MntSweetProducts, MntFruits)            0.081696
# 32213  (MntGoldProds, MntMeatProducts, MntSweetProduc...            0.080357
# 32188        (MntGoldProds, MntSweetProducts, MntFruits)            0.080357
# 33959  (MntGoldProds, MntMeatProducts, MntSweetProduc...            0.080357
# 28203        (MntGoldProds, MntSweetProducts, MntFruits)            0.080357
# 33981  (MntMeatProducts, MntSweetProducts, MntGoldPro...            0.080357
# 33940  (MntGoldProds, MntFruits, MntSweetProducts, In...            0.080357
# 33909        (MntGoldProds, MntSweetProducts, MntFruits)            0.080357
#
#        consequent support   support  confidence      lift  leverage  \
# 30779            0.713393  0.074107    0.907104  1.271535  0.015825
# 30761            0.713393  0.074107    0.907104  1.271535  0.015825
# 24598            0.713393  0.074107    0.907104  1.271535  0.015825
# 32213            0.713393  0.072768    0.905556  1.269364  0.015442
# 32188            0.713393  0.072768    0.905556  1.269364  0.015442
# 33959            0.713393  0.072768    0.905556  1.269364  0.015442
# 28203            0.713393  0.072768    0.905556  1.269364  0.015442
# 33981            0.713393  0.072768    0.905556  1.269364  0.015442
# 33940            0.713393  0.072768    0.905556  1.269364  0.015442
# 33909            0.713393  0.072768    0.905556  1.269364  0.015442
#
#        conviction  zhangs_metric
# 30779    3.085242       0.232547
# 30761    3.085242       0.232547
# 24598    3.085242       0.232547
# 32213    3.034664       0.230746
# 32188    3.034664       0.230746
# 33959    3.034664       0.230746
# 28203    3.034664       0.230746
# 33981    3.034664       0.230746
# 33940    3.034664       0.230746
# 33909    3.034664       0.230746

# %%
rules_sorted = rules.sort_values(by=['confidence'], ascending=False)
rules_sorted.to_csv('rules_by_confidence.csv', index=False)
rules_sorted.head(10)
# Out:
#                                              antecedents  \
# 0                                             (MntWines)
# 3942   (Marital_Status_Married, Education_Master, Mnt...
# 10749        (AcceptedCmp1, MntSweetProducts, MntFruits)
# 3966   (AcceptedCmp5, MntFishProducts, MntSweetProducts)
# 10757  (MntMeatProducts, Response, MntSweetProducts, ...
# 10759  (MntWines, Response, MntSweetProducts, MntFruits)
# 33235  (MntFishProducts, MntSweetProducts, Marital_St...
# 10764            (Response, MntSweetProducts, MntFruits)
# 10774  (Education_2n Cycle, MntWines, MntSweetProduct...
# 25102  (MntFishProducts, MntSweetProducts, Marital_St...
#
#                        consequents  antecedent support  consequent support  \
# 0                         (Income)            0.994196            1.000000
# 3942             (MntMeatProducts)            0.061607            0.999554
# 10749  (MntMeatProducts, MntWines)            0.052232            0.994196
# 3966                    (MntWines)            0.061161            0.994196
# 10757                   (MntWines)            0.119643            0.994196
# 10759            (MntMeatProducts)            0.119643            0.999554
# 33235     (MntWines, MntGoldProds)            0.083929            0.966964
# 10764  (MntMeatProducts, MntWines)            0.119643            0.994196
# 10774            (MntMeatProducts)            0.078571            0.999554
# 25102               (MntGoldProds)            0.083929            0.972768
#
#         support  confidence      lift  leverage  conviction  zhangs_metric
# 0      0.994196         1.0  1.000000  0.000000         NaN       0.000000
# 3942   0.061607         1.0  1.000447  0.000028         inf       0.000476
# 10749  0.052232         1.0  1.005837  0.000303         inf       0.006123
# 3966   0.061161         1.0  1.005837  0.000355         inf       0.006182
# 10757  0.119643         1.0  1.005837  0.000694         inf       0.006592
# 10759  0.119643         1.0  1.000447  0.000053         inf       0.000507
# 33235  0.083929         1.0  1.034164  0.002773         inf       0.036062
# 10764  0.119643         1.0  1.005837  0.000694         inf       0.006592
# 10774  0.078571         1.0  1.000447  0.000035         inf       0.000484
# 25102  0.083929         1.0  1.027994  0.002286         inf       0.029727

# %%
rules_sorted = rules.sort_values(by=['support'], ascending=False)
rules_sorted.to_csv('rules_by_support.csv', index=False)
rules_sorted.head(10)
# Out:
#                      antecedents                  consequents  \
# 4              (MntMeatProducts)                     (Income)
# 5                       (Income)            (MntMeatProducts)
# 0                     (MntWines)                     (Income)
# 1                       (Income)                   (MntWines)
# 151           (MntWines, Income)            (MntMeatProducts)
# 152            (MntMeatProducts)           (MntWines, Income)
# 153                   (MntWines)    (MntMeatProducts, Income)
# 154                     (Income)  (MntMeatProducts, MntWines)
# 149  (MntMeatProducts, MntWines)                     (Income)
# 29                    (MntWines)            (MntMeatProducts)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 4              0.999554            1.000000  0.999554    1.000000  1.000000
# 5              1.000000            0.999554  0.999554    0.999554  1.000000
# 0              0.994196            1.000000  0.994196    1.000000  1.000000
# 1              1.000000            0.994196  0.994196    0.994196  1.000000
# 151            0.994196            0.999554  0.994196    1.000000  1.000447
# 152            0.999554            0.994196  0.994196    0.994640  1.000447
# 153            0.994196            0.999554  0.994196    1.000000  1.000447
# 154            1.000000            0.994196  0.994196    0.994196  1.000000
# 149            0.994196            1.000000  0.994196    1.000000  1.000000
# 29             0.994196            0.999554  0.994196    1.000000  1.000447
#
#      leverage  conviction  zhangs_metric
# 4    0.000000         NaN       0.000000
# 5    0.000000     1.00000       0.000000
# 0    0.000000         NaN       0.000000
# 1    0.000000     1.00000       0.000000
# 151  0.000444         inf       0.076923
# 152  0.000444     1.08285       1.000000
# 153  0.000444         inf       0.076923
# 154  0.000000     1.00000       0.000000
# 149  0.000000         NaN       0.000000
# 29   0.000444         inf       0.076923

# %%
rules_sorted = rules.sort_values(by=['leverage'], ascending=False)
rules_sorted.to_csv('rules_by_leverage.csv', index=False)
rules_sorted.head(10)
# Out:
#                                              antecedents  \
# 25287      (MntMeatProducts, MntFishProducts, MntFruits)
# 25278  (MntGoldProds, MntWines, MntSweetProducts, Inc...
# 15651               (MntFruits, MntFishProducts, Income)
# 15652         (MntGoldProds, MntWines, MntSweetProducts)
# 11163                       (MntFishProducts, MntFruits)
# 25258  (MntGoldProds, MntMeatProducts, MntWines, MntS...
# 25257  (MntFruits, MntMeatProducts, MntFishProducts, ...
# 25307               (MntFruits, MntFishProducts, Income)
# 21924                       (MntFishProducts, MntFruits)
# 21887  (MntGoldProds, MntMeatProducts, MntWines, MntS...
#
#                                              consequents  antecedent support  \
# 25287  (MntGoldProds, MntWines, MntSweetProducts, Inc...            0.735714
# 25278      (MntMeatProducts, MntFishProducts, MntFruits)            0.792411
# 15651         (MntGoldProds, MntWines, MntSweetProducts)            0.735714
# 15652               (MntFruits, MntFishProducts, Income)            0.792411
# 11163         (MntGoldProds, MntWines, MntSweetProducts)            0.735714
# 25258               (MntFruits, MntFishProducts, Income)            0.792411
# 25257         (MntGoldProds, MntWines, MntSweetProducts)            0.735714
# 25307  (MntGoldProds, MntMeatProducts, MntWines, MntS...            0.735714
# 21924  (MntGoldProds, MntMeatProducts, MntWines, MntS...            0.735714
# 21887                       (MntFishProducts, MntFruits)            0.792411
#
#        consequent support   support  confidence      lift  leverage  \
# 25287            0.792411  0.646875    0.879248  1.109586  0.063887
# 25278            0.735714  0.646875    0.816338  1.109586  0.063887
# 15651            0.792411  0.646875    0.879248  1.109586  0.063887
# 15652            0.735714  0.646875    0.816338  1.109586  0.063887
# 11163            0.792411  0.646875    0.879248  1.109586  0.063887
# 25258            0.735714  0.646875    0.816338  1.109586  0.063887
# 25257            0.792411  0.646875    0.879248  1.109586  0.063887
# 25307            0.792411  0.646875    0.879248  1.109586  0.063887
# 21924            0.792411  0.646875    0.879248  1.109586  0.063887
# 21887            0.735714  0.646875    0.816338  1.109586  0.063887
#
#        conviction  zhangs_metric
# 25287    1.719131       0.373697
# 25278    1.438979       0.475760
# 15651    1.719131       0.373697
# 15652    1.438979       0.475760
# 11163    1.719131       0.373697
# 25258    1.438979       0.475760
# 25257    1.719131       0.373697
# 25307    1.719131       0.373697
# 21924    1.719131       0.373697
# 21887    1.438979       0.475760

# %%
rules_sorted = rules.sort_values(by=['conviction'], ascending=True)
rules_sorted.to_csv('rules_by_conviction.csv', index=False)
rules_sorted.head(10)
# Out:
#                                              antecedents  \
# 13866  (MntGoldProds, Education_2n Cycle, MntFishProd...
# 21265  (MntFishProducts, MntSweetProducts, MntGoldPro...
# 21272  (MntGoldProds, Education_2n Cycle, MntFishProd...
# 9450   (Education_2n Cycle, MntFishProducts, MntSweet...
# 9446   (Education_2n Cycle, MntFishProducts, MntSweet...
# 4984   (Education_2n Cycle, MntFishProducts, MntSweet...
# 21404  (MntGoldProds, Marital_Status_Divorced, MntFis...
# 13930  (MntGoldProds, Marital_Status_Divorced, MntFis...
# 21397  (MntFishProducts, MntSweetProducts, Marital_St...
# 9514   (Marital_Status_Divorced, MntFishProducts, Mnt...
#
#                      consequents  antecedent support  consequent support  \
# 13866          (MntMeatProducts)            0.075446            0.999554
# 21265          (MntMeatProducts)            0.075446            0.999554
# 21272  (MntMeatProducts, Income)            0.075446            0.999554
# 9450   (MntMeatProducts, Income)            0.075446            0.999554
# 9446           (MntMeatProducts)            0.075446            0.999554
# 4984           (MntMeatProducts)            0.075446            0.999554
# 21404  (MntMeatProducts, Income)            0.077679            0.999554
# 13930          (MntMeatProducts)            0.077679            0.999554
# 21397          (MntMeatProducts)            0.077679            0.999554
# 9514   (MntMeatProducts, Income)            0.079018            0.999554
#
#         support  confidence      lift  leverage  conviction  zhangs_metric
# 13866  0.075000    0.994083  0.994527 -0.000413    0.075446      -0.005917
# 21265  0.075000    0.994083  0.994527 -0.000413    0.075446      -0.005917
# 21272  0.075000    0.994083  0.994527 -0.000413    0.075446      -0.005917
# 9450   0.075000    0.994083  0.994527 -0.000413    0.075446      -0.005917
# 9446   0.075000    0.994083  0.994527 -0.000413    0.075446      -0.005917
# 4984   0.075000    0.994083  0.994527 -0.000413    0.075446      -0.005917
# 21404  0.077232    0.994253  0.994697 -0.000412    0.077679      -0.005747
# 13930  0.077232    0.994253  0.994697 -0.000412    0.077679      -0.005747
# 21397  0.077232    0.994253  0.994697 -0.000412    0.077679      -0.005747
# 9514   0.078571    0.994350  0.994794 -0.000411    0.079018      -0.005650

# %%
numeric_df = df.select_dtypes(include=[int, float])
model = IsolationForest(contamination=0.1, random_state=42)
model.fit(numeric_df)

df['novelty'] = model.predict(numeric_df)
df['novelty'] = df['novelty'].map({1: 'NO', -1: 'YES'})

df.to_csv('novelty_analysis.csv', index=False)

print("DataFrame with Novelty Labels:")
print(df.head())
# Out:
# DataFrame with Novelty Labels:
#      ID  Year_Birth  Income  Kidhome  Teenhome Dt_Customer  Recency  MntWines  \
# 0  5524        1957       1        0         0  04-09-2012       58         1
# 1  2174        1954       1        1         1  08-03-2014       38         1
# 2  4141        1965       1        0         0  21-08-2013       26         1
# 3  6182        1984       1        1         0  10-02-2014       26         1
# 4  5324        1981       1        1         0  19-01-2014       94         1
#
#    MntFruits  MntMeatProducts  ...  Education_PhD  Marital_Status_Absurd  \
# 0          1                1  ...          False                  False
# 1          1                1  ...          False                  False
# 2          1                1  ...          False                  False
# 3          1                1  ...          False                  False
# 4          1                1  ...           True                  False
#
#    Marital_Status_Alone  Marital_Status_Divorced  Marital_Status_Married  \
# 0                 False                    False                   False
# 1                 False                    False                   False
# 2                 False                    False                   False
# 3                 False                    False                   False
# 4                 False                    False                    True
#
#    Marital_Status_Single  Marital_Status_Together  Marital_Status_Widow  \
# 0                   True                    False                 False
# 1                   True                    False                 False
# 2                  False                     True                 False
# 3                  False                     True                 False
# 4                  False                    False                 False
#
#    Marital_Status_YOLO  novelty
# 0                False       NO
# 1                False       NO
# 2                False       NO
# 3                False       NO
# 4                False       NO
#
# [5 rows x 41 columns]
