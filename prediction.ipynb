# %%
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import KBinsDiscretizer
from mlxtend.frequent_patterns import apriori, association_rules

df = pd.read_csv('market.csv', sep="\t")

continuous_features = ['Income', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']
imputer = SimpleImputer(strategy='mean')
df[continuous_features] = imputer.fit_transform(df[continuous_features])
df[continuous_features] = df[continuous_features].apply(lambda x: x > 0).astype(int)

categorical_features = ['Education', 'Marital_Status']
df = pd.get_dummies(df, columns=categorical_features)

binary_columns = df.columns[df.isin([0, 1]).all()]

frequent_itemsets = apriori(df[binary_columns], min_support=0.05, use_colnames=True)
rules = association_rules(frequent_itemsets, metric='confidence', min_threshold=0.5)

rules['leverage'] = rules['support'] - (rules['antecedent support'] * rules['consequent support'])
rules['conviction'] = (1 - rules['consequent support']) / (1 - rules['confidence'])

rules_sorted = rules.sort_values(by=['lift', 'confidence', 'support', 'leverage', 'conviction'], ascending=False)
rules_sorted.to_csv('association_rules.csv', index=False)

print(rules_sorted.head(10))
# Out:
# /home/sugato/.local/lib/python3.12/site-packages/mlxtend/frequent_patterns/fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                                              antecedents  \
# 24600  (MntMeatProducts, Education_2n Cycle, MntFishP...
# 30764  (MntMeatProducts, Education_2n Cycle, Income, ...
# 30782  (MntMeatProducts, Education_2n Cycle, MntFishP...
# 23345    (MntFishProducts, MntWines, Education_2n Cycle)
# 28203  (MntFishProducts, MntWines, Education_2n Cycle...
# 28221    (MntFishProducts, MntWines, Education_2n Cycle)
# 32189  (MntMeatProducts, MntWines, Education_2n Cycle...
# 32214    (MntFishProducts, MntWines, Education_2n Cycle)
# 33909  (MntMeatProducts, MntWines, Income, Education_...
# 33942  (MntMeatProducts, MntWines, Education_2n Cycle...
#
#                                              consequents  antecedent support  \
# 24600        (MntFruits, MntSweetProducts, MntGoldProds)            0.081696
# 30764        (MntFruits, MntSweetProducts, MntGoldProds)            0.081696
# 30782  (MntFruits, MntSweetProducts, MntGoldProds, In...            0.081696
# 23345        (MntFruits, MntSweetProducts, MntGoldProds)            0.080357
# 28203        (MntFruits, MntSweetProducts, MntGoldProds)            0.080357
# 28221  (MntFruits, MntSweetProducts, MntGoldProds, In...            0.080357
# 32189        (MntFruits, MntSweetProducts, MntGoldProds)            0.080357
# 32214  (MntFruits, MntMeatProducts, MntGoldProds, Mnt...            0.080357
# 33909        (MntFruits, MntSweetProducts, MntGoldProds)            0.080357
# 33942  (MntFruits, MntSweetProducts, MntGoldProds, In...            0.080357
#
#        consequent support   support  confidence      lift  leverage  \
# 24600            0.713393  0.074107    0.907104  1.271535  0.015825
# 30764            0.713393  0.074107    0.907104  1.271535  0.015825
# 30782            0.713393  0.074107    0.907104  1.271535  0.015825
# 23345            0.713393  0.072768    0.905556  1.269364  0.015442
# 28203            0.713393  0.072768    0.905556  1.269364  0.015442
# 28221            0.713393  0.072768    0.905556  1.269364  0.015442
# 32189            0.713393  0.072768    0.905556  1.269364  0.015442
# 32214            0.713393  0.072768    0.905556  1.269364  0.015442
# 33909            0.713393  0.072768    0.905556  1.269364  0.015442
# 33942            0.713393  0.072768    0.905556  1.269364  0.015442
#
#        conviction  zhangs_metric
# 24600    3.085242       0.232547
# 30764    3.085242       0.232547
# 30782    3.085242       0.232547
# 23345    3.034664       0.230746
# 28203    3.034664       0.230746
# 28221    3.034664       0.230746
# 32189    3.034664       0.230746
# 32214    3.034664       0.230746
# 33909    3.034664       0.230746
# 33942    3.034664       0.230746

# %%
rules_sorted = rules.sort_values(by=['lift'], ascending=False)
rules_sorted.to_csv('rules_by_lift.csv', index=False)
rules_sorted.head(10)
# Out:
#                                              antecedents  \
# 24600  (MntMeatProducts, Education_2n Cycle, MntFishP...
# 30782  (MntMeatProducts, Education_2n Cycle, MntFishP...
# 30764  (MntMeatProducts, Education_2n Cycle, Income, ...
# 28221    (MntFishProducts, MntWines, Education_2n Cycle)
# 32214    (MntFishProducts, MntWines, Education_2n Cycle)
# 33983    (MntFishProducts, MntWines, Education_2n Cycle)
# 32189  (MntMeatProducts, MntWines, Education_2n Cycle...
# 33909  (MntMeatProducts, MntWines, Income, Education_...
# 33942  (MntMeatProducts, MntWines, Education_2n Cycle...
# 23345    (MntFishProducts, MntWines, Education_2n Cycle)
#
#                                              consequents  antecedent support  \
# 24600        (MntFruits, MntSweetProducts, MntGoldProds)            0.081696
# 30782  (MntFruits, MntSweetProducts, MntGoldProds, In...            0.081696
# 30764        (MntFruits, MntSweetProducts, MntGoldProds)            0.081696
# 28221  (MntFruits, MntSweetProducts, MntGoldProds, In...            0.080357
# 32214  (MntFruits, MntMeatProducts, MntGoldProds, Mnt...            0.080357
# 33983  (MntMeatProducts, MntGoldProds, Income, MntSwe...            0.080357
# 32189        (MntFruits, MntSweetProducts, MntGoldProds)            0.080357
# 33909        (MntFruits, MntSweetProducts, MntGoldProds)            0.080357
# 33942  (MntFruits, MntSweetProducts, MntGoldProds, In...            0.080357
# 23345        (MntFruits, MntSweetProducts, MntGoldProds)            0.080357
#
#        consequent support   support  confidence      lift  leverage  \
# 24600            0.713393  0.074107    0.907104  1.271535  0.015825
# 30782            0.713393  0.074107    0.907104  1.271535  0.015825
# 30764            0.713393  0.074107    0.907104  1.271535  0.015825
# 28221            0.713393  0.072768    0.905556  1.269364  0.015442
# 32214            0.713393  0.072768    0.905556  1.269364  0.015442
# 33983            0.713393  0.072768    0.905556  1.269364  0.015442
# 32189            0.713393  0.072768    0.905556  1.269364  0.015442
# 33909            0.713393  0.072768    0.905556  1.269364  0.015442
# 33942            0.713393  0.072768    0.905556  1.269364  0.015442
# 23345            0.713393  0.072768    0.905556  1.269364  0.015442
#
#        conviction  zhangs_metric
# 24600    3.085242       0.232547
# 30782    3.085242       0.232547
# 30764    3.085242       0.232547
# 28221    3.034664       0.230746
# 32214    3.034664       0.230746
# 33983    3.034664       0.230746
# 32189    3.034664       0.230746
# 33909    3.034664       0.230746
# 33942    3.034664       0.230746
# 23345    3.034664       0.230746

# %%
rules_sorted = rules.sort_values(by=['confidence'], ascending=False)
rules_sorted.to_csv('rules_by_confidence.csv', index=False)
rules_sorted.head(10)
# Out:
#                                              antecedents  \
# 0                                             (MntWines)
# 7151   (Education_Graduation, MntWines, Marital_Statu...
# 21582  (Education_Graduation, Income, MntSweetProduct...
# 3204         (MntFruits, Education_Graduation, MntWines)
# 7142   (MntMeatProducts, Response, Income, Education_...
# 7143   (Education_Graduation, MntWines, Response, Inc...
# 7144   (MntMeatProducts, Response, Education_Graduation)
# 7145          (Education_Graduation, MntWines, Response)
# 7146            (Education_Graduation, Response, Income)
# 3198           (MntFruits, MntWines, Education_2n Cycle)
#
#                        consequents  antecedent support  consequent support  \
# 0                         (Income)            0.994196            1.000000
# 7151             (MntMeatProducts)            0.052679            0.999554
# 21582            (MntMeatProducts)            0.102232            0.999554
# 3204             (MntMeatProducts)            0.433036            0.999554
# 7142                    (MntWines)            0.067857            0.994196
# 7143             (MntMeatProducts)            0.067857            0.999554
# 7144            (MntWines, Income)            0.067857            0.994196
# 7145     (MntMeatProducts, Income)            0.067857            0.999554
# 7146   (MntMeatProducts, MntWines)            0.067857            0.994196
# 3198             (MntMeatProducts)            0.085268            0.999554
#
#         support  confidence      lift  leverage  conviction  zhangs_metric
# 0      0.994196         1.0  1.000000  0.000000         NaN       0.000000
# 7151   0.052679         1.0  1.000447  0.000024         inf       0.000471
# 21582  0.102232         1.0  1.000447  0.000046         inf       0.000497
# 3204   0.433036         1.0  1.000447  0.000193         inf       0.000787
# 7142   0.067857         1.0  1.005837  0.000394         inf       0.006226
# 7143   0.067857         1.0  1.000447  0.000030         inf       0.000479
# 7144   0.067857         1.0  1.005837  0.000394         inf       0.006226
# 7145   0.067857         1.0  1.000447  0.000030         inf       0.000479
# 7146   0.067857         1.0  1.005837  0.000394         inf       0.006226
# 3198   0.085268         1.0  1.000447  0.000038         inf       0.000488

# %%
rules_sorted = rules.sort_values(by=['support'], ascending=False)
rules_sorted.to_csv('rules_by_support.csv', index=False)
rules_sorted.head(10)
# Out:
#                      antecedents                  consequents  \
# 4              (MntMeatProducts)                     (Income)
# 5                       (Income)            (MntMeatProducts)
# 0                     (MntWines)                     (Income)
# 1                       (Income)                   (MntWines)
# 151           (MntWines, Income)            (MntMeatProducts)
# 152            (MntMeatProducts)           (MntWines, Income)
# 153                   (MntWines)    (MntMeatProducts, Income)
# 154                     (Income)  (MntMeatProducts, MntWines)
# 149  (MntMeatProducts, MntWines)                     (Income)
# 29                    (MntWines)            (MntMeatProducts)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 4              0.999554            1.000000  0.999554    1.000000  1.000000
# 5              1.000000            0.999554  0.999554    0.999554  1.000000
# 0              0.994196            1.000000  0.994196    1.000000  1.000000
# 1              1.000000            0.994196  0.994196    0.994196  1.000000
# 151            0.994196            0.999554  0.994196    1.000000  1.000447
# 152            0.999554            0.994196  0.994196    0.994640  1.000447
# 153            0.994196            0.999554  0.994196    1.000000  1.000447
# 154            1.000000            0.994196  0.994196    0.994196  1.000000
# 149            0.994196            1.000000  0.994196    1.000000  1.000000
# 29             0.994196            0.999554  0.994196    1.000000  1.000447
#
#      leverage  conviction  zhangs_metric
# 4    0.000000         NaN       0.000000
# 5    0.000000     1.00000       0.000000
# 0    0.000000         NaN       0.000000
# 1    0.000000     1.00000       0.000000
# 151  0.000444         inf       0.076923
# 152  0.000444     1.08285       1.000000
# 153  0.000444         inf       0.076923
# 154  0.000000     1.00000       0.000000
# 149  0.000000         NaN       0.000000
# 29   0.000444         inf       0.076923

# %%
rules_sorted = rules.sort_values(by=['leverage'], ascending=False)
rules_sorted.to_csv('rules_by_leverage.csv', index=False)
rules_sorted.head(10)
# Out:
#                                              antecedents  \
# 21930                       (MntFruits, MntFishProducts)
# 25299         (MntSweetProducts, MntWines, MntGoldProds)
# 25249  (MntMeatProducts, MntWines, MntGoldProds, MntS...
# 15676                       (MntFruits, MntFishProducts)
# 15660               (MntFruits, MntFishProducts, Income)
# 11150         (MntSweetProducts, MntWines, MntGoldProds)
# 11169                       (MntFruits, MntFishProducts)
# 25297      (MntFruits, MntMeatProducts, MntFishProducts)
# 21905      (MntFruits, MntMeatProducts, MntFishProducts)
# 25266  (MntFruits, MntMeatProducts, Income, MntFishPr...
#
#                                              consequents  antecedent support  \
# 21930  (MntMeatProducts, MntWines, MntGoldProds, MntS...            0.735714
# 25299  (MntFruits, MntMeatProducts, Income, MntFishPr...            0.792411
# 25249               (MntFruits, MntFishProducts, Income)            0.792411
# 15676  (MntSweetProducts, MntWines, MntGoldProds, Inc...            0.735714
# 15660         (MntSweetProducts, MntWines, MntGoldProds)            0.735714
# 11150                       (MntFruits, MntFishProducts)            0.792411
# 11169         (MntSweetProducts, MntWines, MntGoldProds)            0.735714
# 25297  (MntSweetProducts, MntWines, MntGoldProds, Inc...            0.735714
# 21905         (MntSweetProducts, MntWines, MntGoldProds)            0.735714
# 25266         (MntSweetProducts, MntWines, MntGoldProds)            0.735714
#
#        consequent support   support  confidence      lift  leverage  \
# 21930            0.792411  0.646875    0.879248  1.109586  0.063887
# 25299            0.735714  0.646875    0.816338  1.109586  0.063887
# 25249            0.735714  0.646875    0.816338  1.109586  0.063887
# 15676            0.792411  0.646875    0.879248  1.109586  0.063887
# 15660            0.792411  0.646875    0.879248  1.109586  0.063887
# 11150            0.735714  0.646875    0.816338  1.109586  0.063887
# 11169            0.792411  0.646875    0.879248  1.109586  0.063887
# 25297            0.792411  0.646875    0.879248  1.109586  0.063887
# 21905            0.792411  0.646875    0.879248  1.109586  0.063887
# 25266            0.792411  0.646875    0.879248  1.109586  0.063887
#
#        conviction  zhangs_metric
# 21930    1.719131       0.373697
# 25299    1.438979       0.475760
# 25249    1.438979       0.475760
# 15676    1.719131       0.373697
# 15660    1.719131       0.373697
# 11150    1.438979       0.475760
# 11169    1.719131       0.373697
# 25297    1.719131       0.373697
# 21905    1.719131       0.373697
# 25266    1.719131       0.373697

# %%
rules_sorted = rules.sort_values(by=['conviction'], ascending=True)
rules_sorted.to_csv('rules_by_conviction.csv', index=False)
rules_sorted.head(10)
# Out:
#                                              antecedents  \
# 21265  (MntGoldProds, Income, MntSweetProducts, Educa...
# 21274  (MntSweetProducts, Education_2n Cycle, MntGold...
# 4984   (MntFishProducts, Education_2n Cycle, MntSweet...
# 9446   (MntSweetProducts, Education_2n Cycle, Income,...
# 9452   (MntSweetProducts, Education_2n Cycle, MntFish...
# 13866  (MntSweetProducts, Education_2n Cycle, MntGold...
# 21406  (MntSweetProducts, Marital_Status_Divorced, Mn...
# 13930  (MntSweetProducts, Marital_Status_Divorced, Mn...
# 21397  (Marital_Status_Divorced, MntGoldProds, Income...
# 9510   (MntSweetProducts, Marital_Status_Divorced, In...
#
#                      consequents  antecedent support  consequent support  \
# 21265          (MntMeatProducts)            0.075446            0.999554
# 21274  (MntMeatProducts, Income)            0.075446            0.999554
# 4984           (MntMeatProducts)            0.075446            0.999554
# 9446           (MntMeatProducts)            0.075446            0.999554
# 9452   (MntMeatProducts, Income)            0.075446            0.999554
# 13866          (MntMeatProducts)            0.075446            0.999554
# 21406  (MntMeatProducts, Income)            0.077679            0.999554
# 13930          (MntMeatProducts)            0.077679            0.999554
# 21397          (MntMeatProducts)            0.077679            0.999554
# 9510           (MntMeatProducts)            0.079018            0.999554
#
#         support  confidence      lift  leverage  conviction  zhangs_metric
# 21265  0.075000    0.994083  0.994527 -0.000413    0.075446      -0.005917
# 21274  0.075000    0.994083  0.994527 -0.000413    0.075446      -0.005917
# 4984   0.075000    0.994083  0.994527 -0.000413    0.075446      -0.005917
# 9446   0.075000    0.994083  0.994527 -0.000413    0.075446      -0.005917
# 9452   0.075000    0.994083  0.994527 -0.000413    0.075446      -0.005917
# 13866  0.075000    0.994083  0.994527 -0.000413    0.075446      -0.005917
# 21406  0.077232    0.994253  0.994697 -0.000412    0.077679      -0.005747
# 13930  0.077232    0.994253  0.994697 -0.000412    0.077679      -0.005747
# 21397  0.077232    0.994253  0.994697 -0.000412    0.077679      -0.005747
# 9510   0.078571    0.994350  0.994794 -0.000411    0.079018      -0.005650

# %%
numeric_df = df.select_dtypes(include=[int, float])
model = IsolationForest(contamination=0.1, random_state=42)
model.fit(numeric_df)

df['novelty'] = model.predict(numeric_df)
df['novelty'] = df['novelty'].map({1: 'NO', -1: 'YES'})

df.to_csv('novelty_analysis.csv', index=False)

print("DataFrame with Novelty Labels:")
print(df.head())
# Out:
# DataFrame with Novelty Labels:
#      ID  Year_Birth  Income  Kidhome  Teenhome Dt_Customer  Recency  MntWines  \
# 0  5524        1957       1        0         0  04-09-2012       58         1
# 1  2174        1954       1        1         1  08-03-2014       38         1
# 2  4141        1965       1        0         0  21-08-2013       26         1
# 3  6182        1984       1        1         0  10-02-2014       26         1
# 4  5324        1981       1        1         0  19-01-2014       94         1
#
#    MntFruits  MntMeatProducts  ...  Education_PhD  Marital_Status_Absurd  \
# 0          1                1  ...          False                  False
# 1          1                1  ...          False                  False
# 2          1                1  ...          False                  False
# 3          1                1  ...          False                  False
# 4          1                1  ...           True                  False
#
#    Marital_Status_Alone  Marital_Status_Divorced  Marital_Status_Married  \
# 0                 False                    False                   False
# 1                 False                    False                   False
# 2                 False                    False                   False
# 3                 False                    False                   False
# 4                 False                    False                    True
#
#    Marital_Status_Single  Marital_Status_Together  Marital_Status_Widow  \
# 0                   True                    False                 False
# 1                   True                    False                 False
# 2                  False                     True                 False
# 3                  False                     True                 False
# 4                  False                    False                 False
#
#    Marital_Status_YOLO  novelty
# 0                False       NO
# 1                False       NO
# 2                False       NO
# 3                False       NO
# 4                False       NO
#
# [5 rows x 41 columns]
